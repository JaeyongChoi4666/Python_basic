# %%
import requests
import json

url="http://ihongss.com/json/exam21.json"
data = json.loads(requests.get(url).text)
data1=[]
a=[]
for i in data['boxOfficeResult']['dailyBoxOfficeList']:
    a.append([i.get('rnum'),i.get('rank'),i.get('rankInten'),i.get('rankOldAndNew'),i.get('movieCd'),i.get('movieNm'),
            i.get('openDt'),i.get('salesAmt'),i.get('salesShare'),i.get('salesInten'),i.get('salesChange'),i.get('salesAcc'),
            i.get('audiCnt'),i.get('audiInten'),i.get('audiChange'),i.get('audiAcc'),i.get('scrnCnt'),i.get('showCnt')])
    
    
data1.append(data['boxOfficeResult']['boxofficeType'])
data1.append(data['boxOfficeResult']['showRange'])
data1.append(a)

        
print("------(data1)--------------")
print(data1,type(data1))
# Out:
# ------(data1)--------------
# ...
