# %%
import requests
import bs4

url="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cnt&date=20210520"
response = requests.get(url)
soup = bs4.BeautifulSoup(response.text, 'html.parser') 
soup

#old_content > table > tbody > tr:nth-child(2) > td.title > div > a

arr=[]
for tmp in soup.select("#old_content > table > tbody > tr > td.title > div > a",limit=14):
    print(tmp.text)
    print(tmp.attrs["href"])
    url="https://movie.naver.com"+tmp.attrs["href"]
    response = requests.get(url)
    soup = bs4.BeautifulSoup(response.text, 'html.parser')

    data={"title":tmp.text}
    director=soup.select_one("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(4) > p > a").text
    actors=soup.select_one("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(6) > p").text
    grade=soup.select_one("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(8) > p > a").text
    genre=soup.select_one("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(2) > p > span:nth-child(1) > a").text
    nation=soup.select_one("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(2) > p > span:nth-child(2) > a").text
    runningtime=soup.select_one("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(2) > p > span:nth-child(3)").text
    opendate=soup.select_one("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(2) > p > span:nth-child(4)").text
    point=soup.select_one("#actualPointPersentBasic > div > span > span").text
    audience=soup.select_one("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(10) > div > p.count").text
    
    print("감독",director)
    print("배우:",actors)
    print("등급:",grade)  
    print("장르:",genre)
    print("국가:",nation)
    print("시간:",runningtime)
    print("개봉:",opendate[2:6]+"."+opendate[8:13])
    print(f"평점: {point[7:11]}")
    print(f"누적관객수: {audience}")
    
    data["director"]=director
    data["actors"]=actors
    data["grade"]=grade
    data["genre"]=genre
    data["nation"]=nation
    data["runningtime"]=runningtime
    data["opendate"]=opendate[2:6]+"."+opendate[8:13]
    data["point"]=point[7:11]
            
    print(data)
    arr.append(data)
    print("="*40)
# Out:
# 분노의 질주: 더 얼티메이트
# /movie/bi/mi/basic.nhn?code=189150
# 감독 저스틴 린
# 배우: 빈 디젤(도미닉 토레토), 존 시나(제이콥 토레토), 성 강(한)
# 등급: 12세 관람가
# 장르: 액션
# 국가: 미국
# 시간: 142분
# 개봉: 2021.05.19
# 평점: 9.08
# 누적관객수: 1,132,900명(05.23 기준)
# {'title': '분노의 질주: 더 얼티메이트', 'director': '저스틴 린', 'actors': '빈 디젤(도미닉 토레토), 존 시나(제이콥 토레토), 성 강(한)', 'grade': '12세 관람가', 'genre': '액션', 'nation': '미국', 'runningtime': '142분 ', 'opendate': '2021.05.19', 'point': '9.08'}
# ========================================
# 스파이럴
# /movie/bi/mi/basic.nhn?code=191570
# 감독 대런 린 보우즈만
# 배우: 크리스 록, 사무엘 L. 잭슨, 마리솔 니콜스
# 등급: 청소년 관람불가
# 장르: 스릴러
# 국가: 미국
# 시간: 93분
# 개봉: 2021.05.12
# 평점: 7.86
# 누적관객수: 122,851명(05.23 기준)
# {'title': '스파이럴', 'director': '대런 린 보우즈만', 'actors': '크리스 록, 사무엘 L. 잭슨, 마리솔 니콜스', 'grade': '청소년 관람불가', 'genre': '스릴러', 'nation': '미국', 'runningtime': '93분 ', 'opendate': '2021.05.12', 'point': '7.86'}
# ========================================
# 더 스파이
# /movie/bi/mi/basic.nhn?code=191914
# 감독 도미닉 쿡
# 배우: 베네딕트 컴버배치(그레빌 윈)
# 등급: 15세 관람가
# 장르: 스릴러
# 국가: 미국
# 시간: 112분
# 개봉: 2021.04.28
# 평점: 8.78
# 누적관객수: 303,271명(05.23 기준)
# {'title': '더 스파이', 'director': '도미닉 쿡', 'actors': '베네딕트 컴버배치(그레빌 윈)', 'grade': '15세 관람가', 'genre': '스릴러', 'nation': '미국', 'runningtime': '112분 ', 'opendate': '2021.04.28', 'point': '8.78'}
# ========================================
# 크루즈 패밀리: 뉴 에이지
# /movie/bi/mi/basic.nhn?code=107992
# 감독 조엘 크로포드
# 배우: 엠마 스톤(이프 목소리), 라이언 레이놀즈(가이 목소리), 켈리 마리 트란(던 목소리)
# 등급: 전체 관람가
# 장르: 애니메이션
# 국가: 미국
# 시간: 95분
# 개봉: 2021.05.05
# 평점: 9.34
# 누적관객수: 222,304명(05.23 기준)
# {'title': '크루즈 패밀리: 뉴 에이지', 'director': '조엘 크로포드', 'actors': '엠마 스톤(이프 목소리), 라이언 레이놀즈(가이 목소리), 켈리 마리 트란(던 목소리)', 'grade': '전체 관람가', 'genre': '애니메이션', 'nation': '미국', 'runningtime': '95분 ', 'opendate': '2021.05.05', 'point': '9.34'}
# ========================================
# 극장판 귀멸의 칼날: 무한열차편
# /movie/bi/mi/basic.nhn?code=196051
# 감독 소토자키 하루오
# 배우: 하나에 나츠키(카마도 탄지로 목소리), 키토 아카리(카마도 네즈코 목소리)
# 등급: 15세 관람가
# 장르: 애니메이션
# 국가: 일본
# 시간: 117분
# 개봉: 2021.01.27
# 평점: 9.62
# 누적관객수: 2,044,636명(05.23 기준)
# {'title': '극장판 귀멸의 칼날: 무한열차편', 'director': '소토자키 하루오', 'actors': '하나에 나츠키(카마도 탄지로 목소리), 키토 아카리(카마도 네즈코 목소리)', 'grade': '15세 관람가', 'genre': '애니메이션', 'nation': '일본', 'runningtime': '117분 ', 'opendate': '2021.01.27', 'point': '9.62'}
# ========================================
# 내가 죽기를 바라는 자들
# /movie/bi/mi/basic.nhn?code=203643
# 감독 테일러 쉐리던
# 배우: 안젤리나 졸리, 니콜라스 홀트, 핀 리틀
# 등급: 15세 관람가
# 장르: 범죄
# 국가: 미국
# 시간: 100분
# 개봉: 2021.05.05
# 평점: 7.50
# 누적관객수: 54,888명(05.23 기준)
# {'title': '내가 죽기를 바라는 자들', 'director': '테일러 쉐리던', 'actors': '안젤리나 졸리, 니콜라스 홀트, 핀 리틀', 'grade': '15세 관람가', 'genre': '범죄', 'nation': '미국', 'runningtime': '100분 ', 'opendate': '2021.05.05', 'point': '7.50'}
# ========================================
# 비와 당신의 이야기
# /movie/bi/mi/basic.nhn?code=192620
# 감독 조진모
# 배우: 강하늘(영호), 천우희(소희)
# 등급: 전체 관람가
# 장르: 드라마
# 국가: 한국
# 시간: 117분
# 개봉: 2021.04.28
# 평점: 8.00
# 누적관객수: 365,321명(05.23 기준)
# {'title': '비와 당신의 이야기', 'director': '조진모', 'actors': '강하늘(영호), 천우희(소희)', 'grade': '전체 관람가', 'genre': '드라마', 'nation': '한국', 'runningtime': '117분 ', 'opendate': '2021.04.28', 'point': '8.00'}
# ========================================
# 아들의 이름으로
# /movie/bi/mi/basic.nhn?code=195694
# 감독 이정국
# 배우: 안성기, 윤유선, 박근형
# 등급: 12세 관람가
# 장르: 드라마
# 국가: 한국
# 시간: 90분
# 개봉: 2021.05.12
# 평점: 6.80
# 누적관객수: 22,824명(05.23 기준)
# {'title': '아들의 이름으로', 'director': '이정국', 'actors': '안성기, 윤유선, 박근형', 'grade': '12세 관람가', 'genre': '드라마', 'nation': '한국', 'runningtime': '90분 ', 'opendate': '2021.05.12', 'point': '6.80'}
# ========================================
# 내일의 기억
# /movie/bi/mi/basic.nhn?code=185293
# 감독 서유민
# 배우: 서예지(수진), 김강우(선우)
# 등급: 15세 관람가
# 장르: 미스터리
# 국가: 한국
# 시간: 99분
# 개봉: 2021.04.21
# 평점: 9.03
# 누적관객수: 331,620명(05.23 기준)
# {'title': '내일의 기억', 'director': '서유민', 'actors': '서예지(수진), 김강우(선우)', 'grade': '15세 관람가', 'genre': '미스터리', 'nation': '한국', 'runningtime': '99분 ', 'opendate': '2021.04.21', 'point': '9.03'}
# ========================================
# 도라에몽: 스탠바이미 2
# /movie/bi/mi/basic.nhn?code=200052
# 감독 야기 류이치
# 배우: 윤아영(도라에몽 한국어 목소리), 김정아(진구 한국어 목소리), 김혜성(성인 진구 한국어 목소리)
# 등급: 전체 관람가
# 장르: 애니메이션
# 국가: 일본
# 시간: 96분
# 개봉: 2021.05.19
# 평점: 9.13
# 누적관객수: 59,328명(05.23 기준)
# {'title': '도라에몽: 스탠바이미 2', 'director': '야기 류이치', 'actors': '윤아영(도라에몽 한국어 목소리), 김정아(진구 한국어 목소리), 김혜성(성인 진구 한국어 목소리)', 'grade': '전체 관람가', 'genre': '애니메이션', 'nation': '일본', 'runningtime': '96분 ', 'opendate': '2021.05.19', 'point': '9.13'}
# ========================================
# 미나리
# /movie/bi/mi/basic.nhn?code=187310
# 감독 정이삭
# 배우: 스티븐 연(제이콥), 한예리(모니카), 윤여정(순자)
# 등급: 12세 관람가
# 장르: 드라마
# 국가: 미국
# 시간: 115분
# 개봉: 2021.03.03
# 평점: 8.32
# 누적관객수: 1,125,209명(05.23 기준)
# {'title': '미나리', 'director': '정이삭', 'actors': '스티븐 연(제이콥), 한예리(모니카), 윤여정(순자)', 'grade': '12세 관람가', 'genre': '드라마', 'nation': '미국', 'runningtime': '115분 ', 'opendate': '2021.03.03', 'point': '8.32'}
# ========================================
# 혼자 사는 사람들
# /movie/bi/mi/basic.nhn?code=201863
# 감독 홍성은
# 배우: 공승연(진아), 정다은(수진)
# 등급: 12세 관람가
# 장르: 드라마
# 국가: 한국
# 시간: 90분
# 개봉: 2021.05.19
# 평점: 8.54
# 누적관객수: 7,441명(05.23 기준)
# {'title': '혼자 사는 사람들', 'director': '홍성은', 'actors': '공승연(진아), 정다은(수진)', 'grade': '12세 관람가', 'genre': '드라마', 'nation': '한국', 'runningtime': '90분 ', 'opendate': '2021.05.19', 'point': '8.54'}
# ========================================
# 노매드랜드
# /movie/bi/mi/basic.nhn?code=196215
# 감독 클로이 자오
# 배우: 프란시스 맥도맨드(펀)
# 등급: 12세 관람가
# 장르: 드라마
# 국가: 미국
# 시간: 108분
# 개봉: 2021.04.15
# 평점: 8.62
# 누적관객수: 75,609명(05.23 기준)
# {'title': '노매드랜드', 'director': '클로이 자오', 'actors': '프란시스 맥도맨드(펀)', 'grade': '12세 관람가', 'genre': '드라마', 'nation': '미국', 'runningtime': '108분 ', 'opendate': '2021.04.15', 'point': '8.62'}
# ========================================
# 내겐 너무 소중한 너
# /movie/bi/mi/basic.nhn?code=201898
# 감독 이창원
# 배우: 진구(재식), 정서연(은혜)
# 등급: 12세 관람가
# 장르: 드라마
# 국가: 한국
# 시간: 100분
# 개봉: 2021.05.12
# 평점: 9.33
# 누적관객수: 22,813명(05.23 기준)
# {'title': '내겐 너무 소중한 너', 'director': '이창원', 'actors': '진구(재식), 정서연(은혜)', 'grade': '12세 관람가', 'genre': '드라마', 'nation': '한국', 'runningtime': '100분 ', 'opendate': '2021.05.12', 'point': '9.33'}
# ========================================

# %%
# 수집된 자료를 몽고DB에 저장
# 컬렉션은 exam_movie
# (영화제목, 관람등급, 관객평점, 장르, 상영시간, 개봉일, 감독, 출연배우)

import pymongo

try:
    username = "id125"
    password = "pw125"
    host = "1.234.5.158"
    port = 37017
    dbname = "id125"
    
    conn = pymongo.MongoClient(f'mongodb://{username}:{password}@{host}:{port}/{dbname}')
    db = conn.get_database(dbname)
    collection = db.get_collection("exam_movie")  #table과 같은 개념
    collection.insert_many(arr)
except Exception as e:
    print(e)
finally:
    conn.close()

# %%
import hdfs
import json

client_hdfs = hdfs.InsecureClient('http://1.234.5.158:9870', user='hdfs')


print(arr)

client_hdfs.delete('/id125/ex_20210525.json')

with client_hdfs.write('/id125/ex_20210525.json', encoding="utf-8") as writer:
    json.dump(arr,writer)
    
# 5. 확인 크롬에서  http://1.234.5.158:9870/explorer.html#/
# Out:
# [{'title': '분노의 질주: 더 얼티메이트', 'director': '저스틴 린', 'actors': '빈 디젤(도미닉 토레토), 존 시나(제이콥 토레토), 성 강(한)', 'grade': '12세 관람가', 'genre': '액션', 'nation': '미국', 'runningtime': '142분 ', 'opendate': '2021.05.19', 'point': '9.08'}, {'title': '스파이럴', 'director': '대런 린 보우즈만', 'actors': '크리스 록, 사무엘 L. 잭슨, 마리솔 니콜스', 'grade': '청소년 관람불가', 'genre': '스릴러', 'nation': '미국', 'runningtime': '93분 ', 'opendate': '2021.05.12', 'point': '7.86'}, {'title': '더 스파이', 'director': '도미닉 쿡', 'actors': '베네딕트 컴버배치(그레빌 윈)', 'grade': '15세 관람가', 'genre': '스릴러', 'nation': '미국', 'runningtime': '112분 ', 'opendate': '2021.04.28', 'point': '8.78'}, {'title': '크루즈 패밀리: 뉴 에이지', 'director': '조엘 크로포드', 'actors': '엠마 스톤(이프 목소리), 라이언 레이놀즈(가이 목소리), 켈리 마리 트란(던 목소리)', 'grade': '전체 관람가', 'genre': '애니메이션', 'nation': '미국', 'runningtime': '95분 ', 'opendate': '2021.05.05', 'point': '9.34'}, {'title': '극장판 귀멸의 칼날: 무한열차편', 'director': '소토자키 하루오', 'actors': '하나에 나츠키(카마도 탄지로 목소리), 키토 아카리(카마도 네즈코 목소리)', 'grade': '15세 관람가', 'genre': '애니메이션', 'nation': '일본', 'runningtime': '117분 ', 'opendate': '2021.01.27', 'point': '9.62'}, {'title': '내가 죽기를 바라는 자들', 'director': '테일러 쉐리던', 'actors': '안젤리나 졸리, 니콜라스 홀트, 핀 리틀', 'grade': '15세 관람가', 'genre': '범죄', 'nation': '미국', 'runningtime': '100분 ', 'opendate': '2021.05.05', 'point': '7.50'}, {'title': '비와 당신의 이야기', 'director': '조진모', 'actors': '강하늘(영호), 천우희(소희)', 'grade': '전체 관람가', 'genre': '드라마', 'nation': '한국', 'runningtime': '117분 ', 'opendate': '2021.04.28', 'point': '8.00'}, {'title': '아들의 이름으로', 'director': '이정국', 'actors': '안성기, 윤유선, 박근형', 'grade': '12세 관람가', 'genre': '드라마', 'nation': '한국', 'runningtime': '90분 ', 'opendate': '2021.05.12', 'point': '6.80'}, {'title': '내일의 기억', 'director': '서유민', 'actors': '서예지(수진), 김강우(선우)', 'grade': '15세 관람가', 'genre': '미스터리', 'nation': '한국', 'runningtime': '99분 ', 'opendate': '2021.04.21', 'point': '9.03'}, {'title': '도라에몽: 스탠바이미 2', 'director': '야기 류이치', 'actors': '윤아영(도라에몽 한국어 목소리), 김정아(진구 한국어 목소리), 김혜성(성인 진구 한국어 목소리)', 'grade': '전체 관람가', 'genre': '애니메이션', 'nation': '일본', 'runningtime': '96분 ', 'opendate': '2021.05.19', 'point': '9.13'}, {'title': '미나리', 'director': '정이삭', 'actors': '스티븐 연(제이콥), 한예리(모니카), 윤여정(순자)', 'grade': '12세 관람가', 'genre': '드라마', 'nation': '미국', 'runningtime': '115분 ', 'opendate': '2021.03.03', 'point': '8.32'}, {'title': '혼자 사는 사람들', 'director': '홍성은', 'actors': '공승연(진아), 정다은(수진)', 'grade': '12세 관람가', 'genre': '드라마', 'nation': '한국', 'runningtime': '90분 ', 'opendate': '2021.05.19', 'point': '8.54'}, {'title': '노매드랜드', 'director': '클로이 자오', 'actors': '프란시스 맥도맨드(펀)', 'grade': '12세 관람가', 'genre': '드라마', 'nation': '미국', 'runningtime': '108분 ', 'opendate': '2021.04.15', 'point': '8.62'}, {'title': '내겐 너무 소중한 너', 'director': '이창원', 'actors': '진구(재식), 정서연(은혜)', 'grade': '12세 관람가', 'genre': '드라마', 'nation': '한국', 'runningtime': '100분 ', 'opendate': '2021.05.12', 'point': '9.33'}]
