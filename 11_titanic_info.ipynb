# %%
import requests
import json

url="https://raw.githubusercontent.com/IBM/taxinomitis/master/resources/datasets/numbers/titanic.json"
reponse = requests.get(url).text
# print(data, type(data))  # str

data = json.loads(reponse) 
# print(data["metadata"])

fields = []
for tmp in data["metadata"]["fields"]:
    fields.append(tmp['name'].replace(".","").replace(" ","_"))

fields.append('survived')
print(fields)

arr = []
for tmp in data["data"]["survived"]:
    tmp1 = { fields[0]:int(tmp[0]), 
             fields[1]:tmp[1],
             fields[2]:float(tmp[2]),
             fields[3]:int(tmp[3]),
             fields[4]:int(tmp[4]),
             fields[5]:float(tmp[5]),
             fields[6]:tmp[6],
             fields[7]:1 }
    arr.append(tmp1)

    
for tmp in data["data"]["did_not_survive"]:
    tmp1 = { fields[0]:int(tmp[0]), 
             fields[1]:tmp[1],
             fields[2]:float(tmp[2]),
             fields[3]:int(tmp[3]),
             fields[4]:int(tmp[4]),
             fields[5]:float(tmp[5]),
             fields[6]:tmp[6],
             fields[7]:0 }
    arr.append(tmp1)
    
print(arr)
# Out:
# ['ticket_class', 'gender', 'age', 'sibl_sp', 'par_ch', 'ticket_fare', 'embarked', 'survived']
# [{'ticket_class': 3, 'gender': 'male', 'age': 0.42, 'sibl_sp': 0, 'par_ch': 1, 'ticket_fare': 8.5167, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'female', 'age': 0.75, 'sibl_sp': 2, 'par_ch': 1, 'ticket_fare': 19.2583, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'female', 'age': 0.75, 'sibl_sp': 2, 'par_ch': 1, 'ticket_fare': 19.2583, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'female', 'age': 1.0, 'sibl_sp': 0, 'par_ch': 2, 'ticket_fare': 15.7417, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 2, 'gender': 'male', 'age': 1.0, 'sibl_sp': 0, 'par_ch': 2, 'ticket_fare': 37.0042, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 2, 'gender': 'female', 'age': 3.0, 'sibl_sp': 1, 'par_ch': 2, 'ticket_fare': 41.5792, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'female', 'age': 4.0, 'sibl_sp': 0, 'par_ch': 1, 'ticket_fare': 13.4167, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'female', 'age': 5.0, 'sibl_sp': 2, 'par_ch': 1, 'ticket_fare': 19.2583, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'male', 'age': 12.0, 'sibl_sp': 1, 'par_ch': 0, 'ticket_fare': 11.2417, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'female', 'age': 13.0, 'sibl_sp': 0, 'par_ch': 0, 'ticket_fare': 7.2292, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 2, 'gender': 'female', 'age': 14.0, 'sibl_sp': 1, 'par_ch': 0, 'ticket_fare': 30.0708, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'female', 'age': 14.0, 'sibl_sp': 1, 'par_ch': 0, 'ticket_fare': 11.2417, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'female', 'age': 15.0, 'sibl_sp': 1, 'par_ch': 0, 'ticket_fare': 14.4542, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'female', 'age': 15.0, 'sibl_sp': 0, 'par_ch': 0, 'ticket_fare': 7.225, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 1, 'gender': 'female', 'age': 16.0, 'sibl_sp': 0, 'par_ch': 1, 'ticket_fare': 57.9792, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 1, 'gender': 'female', 'age': 17.0, 'sibl_sp': 1, 'par_ch': 0, 'ticket_fare': 108.9, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 2, 'gender': 'female', 'age': 17.0, 'sibl_sp': 0, 'par_ch': 0, 'ticket_fare': 12.0, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 1, 'gender': 'male', 'age': 17.0, 'sibl_sp': 0, 'par_ch': 2, 'ticket_fare': 110.8833, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 1, 'gender': 'female', 'age': 18.0, 'sibl_sp': 2, 'par_ch': 2, 'ticket_fare': 262.375, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 1, 'gender': 'female', 'age': 18.0, 'sibl_sp': 1, 'par_ch': 0, 'ticket_fare': 227.525, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 1, 'gender': 'female', 'age': 19.0, 'sibl_sp': 1, 'par_ch': 0, 'ticket_fare': 91.0792, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'male', 'age': 20.0, 'sibl_sp': 1, 'par_ch': 1, 'ticket_fare': 15.7417, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'male', 'age': 20.0, 'sibl_sp': 0, 'par_ch': 0, 'ticket_fare': 7.2292, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 1, 'gender': 'female', 'age': 21.0, 'sibl_sp': 2, 'par_ch': 2, 'ticket_fare': 262.375, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 1, 'gender': 'female', 'age': 22.0, 'sibl_sp': 0, 'par_ch': 2, 'ticket_fare': 49.5, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 3, 'gender': 'male', 'age': 22.0, 'sibl_sp': 0, 'par_ch': 0, 'ticket_fare': 7.225, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 2, 'gender': 'female', 'age': 22.0, 'sibl_sp': 1, 'par_ch': 2, 'ticket_fare': 41.5792, 'embarked': 'Cherbourg', 'survived': 1}, {'ticket_class': 1, 'gender': 'male', 'age': 23.0, 'sibl_sp': 0, 'par_ch': 1, 'ticket_fare': 63.3583, 'embarked': 'Ch ...
